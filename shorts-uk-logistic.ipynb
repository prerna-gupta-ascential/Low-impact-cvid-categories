# %%
from prophet import Prophet
import pandas as pd

# %%
d=pd.read_excel(r"C:\Users\prernagupta\Desktop\shorts-uk.xlsx")

# %%
d
# Out:
#                       TREND     BASE START_DATE       FSI       NSI  \
# 0    Shorts Super Shorts Uk  Apparel 2016-01-04  0.012823  0.008946
# 1    Shorts Super Shorts Uk  Apparel 2016-01-11  0.013095  0.009735
# 2    Shorts Super Shorts Uk  Apparel 2016-01-18  0.013080  0.010744
# 3    Shorts Super Shorts Uk  Apparel 2016-01-25  0.013066  0.011940
# 4    Shorts Super Shorts Uk  Apparel 2016-02-01  0.012674  0.013289
# ..                      ...      ...        ...       ...       ...
# 338  Shorts Super Shorts Uk  Apparel 2022-06-27       NaN       NaN
# 339  Shorts Super Shorts Uk  Apparel 2022-07-04       NaN       NaN
# 340  Shorts Super Shorts Uk  Apparel 2022-07-11       NaN       NaN
# 341  Shorts Super Shorts Uk  Apparel 2022-07-18       NaN       NaN
# 342  Shorts Super Shorts Uk  Apparel 2022-07-25       NaN       NaN
#
#      FSI_YHAT_LOWER  FSI_YHAT  FSI_YHAT_UPPER  NSI_YHAT_LOWER  NSI_YHAT  ...  \
# 0          0.010228  0.012002        0.013831        0.002455  0.006619  ...
# 1          0.010056  0.011692        0.013519        0.003324  0.007237  ...
# 2          0.009624  0.011415        0.013020        0.004183  0.007956  ...
# 3          0.009581  0.011198        0.013027        0.004693  0.008781  ...
# 4          0.009429  0.011061        0.012899        0.005431  0.009713  ...
# ..              ...       ...             ...             ...       ...  ...
# 338        0.023613  0.025322        0.027123        0.043488  0.047754  ...
# 339        0.023957  0.025490        0.027388        0.039365  0.043859  ...
# 340        0.023647  0.025491        0.027104        0.035692  0.039817  ...
# 341        0.023601  0.025320        0.027003        0.031644  0.035765  ...
# 342        0.023332  0.024996        0.026691        0.027658  0.031847  ...
#
#      MARKDOWN_INDEX  FASHION_LEADERS_INDEX  TRENDING_INDEX  CATWALK_IMPACT  \
# 0          1.146393               0.524518        0.634499             0.0
# 1          1.131434               0.533869        0.769998             0.0
# 2          1.117044               0.543012        0.896334             0.0
# 3          1.103222               0.551946        1.013509             0.0
# 4          1.089968               0.560671        1.121522             0.0
# ..              ...                    ...             ...             ...
# 338             NaN                    NaN             NaN             0.0
# 339             NaN                    NaN             NaN             0.0
# 340             NaN                    NaN             NaN             0.0
# 341             NaN                    NaN             NaN             0.0
# 342             NaN                    NaN             NaN             0.0
#
#                                FSI_PIVOT_POINTS  NSI_PIVOT_POINTS  \
# 0    ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 1    ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 2    ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 3    ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 4    ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# ..                                          ...               ...
# 338  ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 339  ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 340  ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 341  ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
# 342  ['2019-08-12', '2020-05-25', '2021-03-08']    ['2016-01-11']
#
#                  CREATED_AT    CREATED_BY          LEVELS REGION
# 0   2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 1   2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 2   2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 3   2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 4   2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# ..                      ...           ...             ...    ...
# 338 2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 339 2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 340 2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 341 2021-09-06 16:16:02.596  camillereyes  Super Category     UK
# 342 2021-09-06 16:16:02.596  camillereyes  Super Category     UK
#
# [343 rows x 22 columns]

# %%
d=d.iloc[:, [2,3]]

# %%
df=d.dropna()
df.columns = ['ds', 'y']
df['ds']= pd.to_datetime(df['ds'])
# Out:
# <ipython-input-5-ec1e916fc466>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ds']= pd.to_datetime(df['ds'])

# %%
df
# Out:
#             ds         y
# 0   2016-01-04  0.012823
# 1   2016-01-11  0.013095
# 2   2016-01-18  0.013080
# 3   2016-01-25  0.013066
# 4   2016-02-01  0.012674
# ..         ...       ...
# 286 2021-06-28  0.033493
# 287 2021-07-05  0.034659
# 288 2021-07-12  0.035434
# 289 2021-07-19  0.034273
# 290 2021-07-26  0.033977
#
# [291 rows x 2 columns]

# %%
from prophet.plot import plot_yearly
m = Prophet().fit(df)
a = plot_yearly(m)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.plot import add_changepoints_to_plot
m = Prophet()
# define the model
# fit the model
m.fit(df)
future = m.make_future_dataframe(periods=100, freq='W')
#prop only uses weekly seasonlity, and change points for first 80%
fcst = m.predict(future)
fig = m.plot(fcst)
a = add_changepoints_to_plot(fig.gca(), m, fcst)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#logitsic, caps floors 
df['cap'] = 0.04
df['floor'] = 0.01
m = Prophet(yearly_seasonality=True, changepoint_range=1.0  ,changepoint_prior_scale=0.05, growth='logistic')

m.fit(df)
q=m.predict(df)
future = m.make_future_dataframe(periods=100, freq='W')
future['cap'] = 0.04
future['floor'] = 0.01
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# <ipython-input-12-23b77d32ed00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cap'] = 0.04
# <ipython-input-12-23b77d32ed00>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['floor'] = 0.01
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(m, initial='730 days', period='180 days', horizon = '365 days')
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')
# Out:
# INFO:prophet:Making 6 forecasts with cutoffs between 2018-02-07 00:00:00 and 2020-07-26 00:00:00
#   0%|          | 0/6 [00:00<?, ?it/s]
