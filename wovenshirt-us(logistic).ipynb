# %%
from prophet import Prophet
import pandas as pd

# %%
d=pd.read_excel(r"C:\Users\prernagupta\Desktop\wovenshirt-us.xlsx")

# %%
d
# Out:
#                                        TREND     BASE START_DATE       FSI  \
# 0    Woven Shirt Super Woven Shirt Blouse Us  Apparel 2016-01-04  0.098515
# 1    Woven Shirt Super Woven Shirt Blouse Us  Apparel 2016-01-11  0.098015
# 2    Woven Shirt Super Woven Shirt Blouse Us  Apparel 2016-01-18  0.098980
# 3    Woven Shirt Super Woven Shirt Blouse Us  Apparel 2016-01-25  0.099731
# 4    Woven Shirt Super Woven Shirt Blouse Us  Apparel 2016-02-01  0.100155
# ..                                       ...      ...        ...       ...
# 338  Woven Shirt Super Woven Shirt Blouse Us  Apparel 2022-06-27       NaN
# 339  Woven Shirt Super Woven Shirt Blouse Us  Apparel 2022-07-04       NaN
# 340  Woven Shirt Super Woven Shirt Blouse Us  Apparel 2022-07-11       NaN
# 341  Woven Shirt Super Woven Shirt Blouse Us  Apparel 2022-07-18       NaN
# 342  Woven Shirt Super Woven Shirt Blouse Us  Apparel 2022-07-25       NaN
#
#           NSI  FSI_YHAT_LOWER  FSI_YHAT  FSI_YHAT_UPPER  NSI_YHAT_LOWER  \
# 0    0.124149        0.097756  0.100561        0.103721        0.111731
# 1    0.121778        0.098066  0.100830        0.103686        0.112989
# 2    0.120153        0.098170  0.101072        0.104028        0.114039
# 3    0.119194        0.098495  0.101271        0.104042        0.114939
# 4    0.118820        0.098612  0.101426        0.104177        0.115562
# ..        ...             ...       ...             ...             ...
# 338       NaN        0.071772  0.075101        0.078660        0.066708
# 339       NaN        0.071330  0.074707        0.077780        0.065799
# 340       NaN        0.070730  0.074255        0.077477        0.064739
# 341       NaN        0.070204  0.073781        0.077034        0.063289
# 342       NaN        0.069818  0.073326        0.076747        0.061597
#
#      NSI_YHAT  ...  MARKDOWN_INDEX  FASHION_LEADERS_INDEX  TRENDING_INDEX  \
# 0    0.115080  ...        0.975673               0.427213        1.225546
# 1    0.116395  ...        0.976115               0.424205        1.222043
# 2    0.117562  ...        0.976572               0.421359        1.218875
# 3    0.118583  ...        0.977044               0.418676        1.216041
# 4    0.119492  ...        0.977532               0.416154        1.213541
# ..        ...  ...             ...                    ...             ...
# 338  0.072596  ...             NaN                    NaN             NaN
# 339  0.071475  ...             NaN                    NaN             NaN
# 340  0.070206  ...             NaN                    NaN             NaN
# 341  0.068827  ...             NaN                    NaN             NaN
# 342  0.067372  ...             NaN                    NaN             NaN
#
#      CATWALK_IMPACT              FSI_PIVOT_POINTS  \
# 0          0.033023  ['2016-01-11', '2017-07-31']
# 1          0.067406  ['2016-01-11', '2017-07-31']
# 2          0.084419  ['2016-01-11', '2017-07-31']
# 3          0.094971  ['2016-01-11', '2017-07-31']
# 4          0.105524  ['2016-01-11', '2017-07-31']
# ..              ...                           ...
# 338        0.000000  ['2016-01-11', '2017-07-31']
# 339        0.000000  ['2016-01-11', '2017-07-31']
# 340        0.000000  ['2016-01-11', '2017-07-31']
# 341        0.000000  ['2016-01-11', '2017-07-31']
# 342        0.000000  ['2016-01-11', '2017-07-31']
#
#                  NSI_PIVOT_POINTS              CREATED_AT    CREATED_BY  \
# 0    ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 1    ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 2    ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 3    ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 4    ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# ..                            ...                     ...           ...
# 338  ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 339  ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 340  ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 341  ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
# 342  ['2016-01-11', '2017-04-17'] 2021-09-06 16:16:02.596  camillereyes
#
#              LEVELS REGION
# 0    Super Category     US
# 1    Super Category     US
# 2    Super Category     US
# 3    Super Category     US
# 4    Super Category     US
# ..              ...    ...
# 338  Super Category     US
# 339  Super Category     US
# 340  Super Category     US
# 341  Super Category     US
# 342  Super Category     US
#
# [343 rows x 22 columns]

# %%
d=d.iloc[:, [2,3]]

# %%
df=d.dropna()
df.columns = ['ds', 'y']
df['ds']= pd.to_datetime(df['ds'])
# Out:
# <ipython-input-21-ec1e916fc466>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ds']= pd.to_datetime(df['ds'])

# %%
df
# Out:
#             ds         y
# 0   2016-01-04  0.098515
# 1   2016-01-11  0.098015
# 2   2016-01-18  0.098980
# 3   2016-01-25  0.099731
# 4   2016-02-01  0.100155
# ..         ...       ...
# 286 2021-06-28  0.085398
# 287 2021-07-05  0.086549
# 288 2021-07-12  0.084012
# 289 2021-07-19  0.085035
# 290 2021-07-26  0.079800
#
# [291 rows x 2 columns]

# %%
from prophet.plot import plot_yearly
m = Prophet().fit(df)
a = plot_yearly(m)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.plot import add_changepoints_to_plot
m = Prophet()
# define the model
# fit the model
m.fit(df)
future = m.make_future_dataframe(periods=100, freq='W')
#prop only uses weekly seasonlity, and change points for first 80%
fcst = m.predict(future)
fig = m.plot(fcst)
a = add_changepoints_to_plot(fig.gca(), m, fcst)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.plot import add_changepoints_to_plot
m = Prophet(yearly_seasonality=True, changepoint_range=1.0  ,changepoint_prior_scale=0.05, growth='linear')
# define the model
# fit the model
m.fit(df)

future = m.make_future_dataframe(periods=100, freq='W')
#prop only uses weekly seasonlity, and change points for first 80%
fcst = m.predict(future)
fig = m.plot(fcst)
a = add_changepoints_to_plot(fig.gca(), m, fcst)
fig = m.plot(fcst)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#logitsic, caps floors 
df['cap'] = 0.14
df['floor'] = 0.06
m = Prophet(yearly_seasonality=True, changepoint_range=1.0  ,changepoint_prior_scale=0.05, growth='logistic')

m.fit(df)
q=m.predict(df)
future = m.make_future_dataframe(periods=100, freq='W')
future['cap'] = 0.14
future['floor'] = 0.06
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# <ipython-input-27-16d174416c72>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cap'] = 0.14
# <ipython-input-27-16d174416c72>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['floor'] = 0.06
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(m, initial='730 days', period='180 days', horizon = '365 days')
# Out:
# INFO:prophet:Making 6 forecasts with cutoffs between 2018-02-07 00:00:00 and 2020-07-26 00:00:00
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0 36 days  0.000005  0.002339  0.001728  0.016263  0.013642  0.016051
# 1 37 days  0.000006  0.002350  0.001744  0.016374  0.013642  0.016160
# 2 39 days  0.000006  0.002412  0.001833  0.017225  0.015337  0.017024
# 3 40 days  0.000007  0.002646  0.002006  0.018752  0.017118  0.018505
# 4 41 days  0.000007  0.002652  0.002012  0.018880  0.017118  0.018649
#
#    coverage
# 0  0.580645
# 1  0.548387
# 2  0.516129
# 3  0.483871
# 4  0.483871

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')
