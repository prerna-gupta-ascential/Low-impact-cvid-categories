# %%
from prophet import Prophet
import pandas as pd

# %%
d=pd.read_excel(r"C:\Users\prernagupta\Desktop\intimates.xlsx")

# %%
d
# Out:
#                      TREND                          BASE START_DATE       FSI  \
# 0    Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2016-01-04  0.031744
# 1    Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2016-01-11  0.031995
# 2    Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2016-01-18  0.030864
# 3    Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2016-01-25  0.031055
# 4    Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2016-02-01  0.030881
# ..                     ...                           ...        ...       ...
# 345  Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2022-08-15       NaN
# 346  Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2022-08-22       NaN
# 347  Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2022-08-29       NaN
# 348  Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2022-09-05       NaN
# 349  Bodysuit Intimates Uk  Lingerie/Intimates/Underwear 2022-09-12       NaN
#
#           NSI  FSI_YHAT_LOWER  FSI_YHAT  FSI_YHAT_UPPER  NSI_YHAT_LOWER  \
# 0    0.015596        0.034737  0.040274        0.045372        0.020352
# 1    0.017029        0.034859  0.040076        0.045121        0.019916
# 2    0.018293        0.034302  0.039916        0.045364        0.018311
# 3    0.019382        0.034626  0.039808        0.045008        0.018257
# 4    0.020292        0.034278  0.039748        0.044987        0.017545
# ..        ...             ...       ...             ...             ...
# 345       NaN        0.024790  0.029934        0.035412        0.011371
# 346       NaN        0.024509  0.029906        0.035002        0.010936
# 347       NaN        0.024523  0.029900        0.035455        0.010666
# 348       NaN        0.024907  0.029917        0.034909        0.010615
# 349       NaN        0.024716  0.029949        0.035472        0.010444
#
#      NSI_YHAT  ...  MARKDOWN_INDEX  FASHION_LEADERS_INDEX  TRENDING_INDEX  \
# 0    0.029264  ...        0.748159               0.422897        0.492041
# 1    0.027969  ...        0.746743               0.454848        0.543989
# 2    0.027064  ...        0.745408               0.485677        0.588971
# 3    0.026673  ...        0.744155               0.515385        0.626987
# 4    0.026818  ...        0.742985               0.543970        0.658037
# ..        ...  ...             ...                    ...             ...
# 345  0.019552  ...             NaN                    NaN             NaN
# 346  0.019188  ...             NaN                    NaN             NaN
# 347  0.018887  ...             NaN                    NaN             NaN
# 348  0.018747  ...             NaN                    NaN             NaN
# 349  0.018829  ...             NaN                    NaN             NaN
#
#      CATWALK_IMPACT              FSI_PIVOT_POINTS  NSI_PIVOT_POINTS  \
# 0          0.106773  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 1          0.238714  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 2          0.298964  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 3          0.336335  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 4          0.373705  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# ..              ...                           ...               ...
# 345        0.000000  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 346        0.000000  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 347        0.000000  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 348        0.000000  ['2017-05-08', '2018-08-13']    ['2016-01-11']
# 349        0.000000  ['2017-05-08', '2018-08-13']    ['2016-01-11']
#
#                  CREATED_AT    CREATED_BY LEVELS REGION
# 0   2021-09-20 18:39:21.263  camillereyes  Style     UK
# 1   2021-09-20 18:39:21.263  camillereyes  Style     UK
# 2   2021-09-20 18:39:21.263  camillereyes  Style     UK
# 3   2021-09-20 18:39:21.263  camillereyes  Style     UK
# 4   2021-09-20 18:39:21.263  camillereyes  Style     UK
# ..                      ...           ...    ...    ...
# 345 2021-09-20 18:39:21.263  camillereyes  Style     UK
# 346 2021-09-20 18:39:21.263  camillereyes  Style     UK
# 347 2021-09-20 18:39:21.263  camillereyes  Style     UK
# 348 2021-09-20 18:39:21.263  camillereyes  Style     UK
# 349 2021-09-20 18:39:21.263  camillereyes  Style     UK
#
# [350 rows x 22 columns]

# %%
d=d.iloc[:, [2,3]]

# %%
df=d.dropna()
df.columns = ['ds', 'y']
df['ds']= pd.to_datetime(df['ds'])
# Out:
# <ipython-input-41-ec1e916fc466>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ds']= pd.to_datetime(df['ds'])

# %%
df
# Out:
#             ds         y
# 0   2016-01-04  0.031744
# 1   2016-01-11  0.031995
# 2   2016-01-18  0.030864
# 3   2016-01-25  0.031055
# 4   2016-02-01  0.030881
# ..         ...       ...
# 293 2021-08-16  0.030975
# 294 2021-08-23  0.031761
# 295 2021-08-30  0.031719
# 296 2021-09-06  0.032087
# 297 2021-09-13  0.031832
#
# [298 rows x 2 columns]

# %%
from prophet.plot import plot_yearly
m = Prophet().fit(df)
a = plot_yearly(m)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.plot import add_changepoints_to_plot
m = Prophet()
# define the model
# fit the model
m.fit(df)
future = m.make_future_dataframe(periods=100, freq='W')
#prop only uses weekly seasonlity, and change points for first 80%
fcst = m.predict(future)
fig = m.plot(fcst)
a = add_changepoints_to_plot(fig.gca(), m, fcst)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.plot import add_changepoints_to_plot
m = Prophet(yearly_seasonality=True, changepoint_range=1.0  ,changepoint_prior_scale=0.05, growth='linear')
# define the model
# fit the model
m.fit(df)

future = m.make_future_dataframe(periods=100, freq='W')
#prop only uses weekly seasonlity, and change points for first 80%
fcst = m.predict(future)
fig = m.plot(fcst)
a = add_changepoints_to_plot(fig.gca(), m, fcst)
fig = m.plot(fcst)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(m, initial='730 days', period='180 days', horizon = '365 days')
# Out:
# INFO:prophet:Making 6 forecasts with cutoffs between 2018-03-28 00:00:00 and 2020-09-13 00:00:00
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0 36 days  0.000008  0.002849  0.002336  0.064126  0.050714  0.062766
# 1 37 days  0.000009  0.002942  0.002463  0.067501  0.056851  0.066343
# 2 39 days  0.000009  0.002949  0.002469  0.067991  0.056851  0.066505
# 3 40 days  0.000009  0.003033  0.002550  0.070290  0.067762  0.068619
# 4 41 days  0.000009  0.002981  0.002512  0.069339  0.067762  0.068053
#
#    coverage
# 0  0.548387
# 1  0.516129
# 2  0.516129
# 3  0.483871
# 4  0.483871

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')
